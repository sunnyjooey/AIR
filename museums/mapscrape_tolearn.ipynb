# %%
import requests
import json
import ast

# %%
import pandas as pd
d = pd.read_csv('./IRS_ToLearnOnly_rev2.csv')
# Out:
# /Users/sjlee/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (27,30,31,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
d.head()
# Out:
#    v1        ein                                              name  \
# 0   2  844082111         boulder ridge wild animal park foundation
# 1   4  611638654                       animal park care rescue inc
# 2   7  591230940           florida botanical garden foundation inc
# 3   9  990107937                  friend honolulu botanical garden
# 4  14  930843369  friend delbert hunter arboretum botanical garden
#
#                   ico                   street        city state         zip  \
# 0    % DAVID HOEKSTRA   8313 PRATT LAKE AVE SE        ALTO    MI  49302-9610
# 1    % ROBERT L CANDY  10105 COTTAGE INN LN NE  CUMBERLAND    MD  21502-8250
# 2                 NaN        12520 ULMERTON RD       LARGO    FL  33774-3602
# 3                 NaN      180 N VINEYARD BLVD    HONOLULU    HI  96817-3937
# 4  % HUNTER ARBORETUM               PO BOX 604      DALLAS    OR  97338-0604
#
#    group  subsection  ...  act2  act3  no_act  no_both  act_possibly  \
# ...

# %%
import random
randomlist = random.sample(range(d.shape[0]), 100)

# %%
d.loc[randomlist,:].to_csv('./random100.csv',index=False)

# %%
api_key = "AIzaSyCNh5Hdo6NCnx1-wvKgSIxrInJorxOBPks"

for i in randomlist:
    row = d.loc[i, :]
    place = '{}, {}, {}, USA'.format(row['name'], row['city'], row['state'])
    url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={}&inputtype=textquery&key={}".format(place, api_key)

    payload={}
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)
    
    try:
        place_id = json.loads(response.text)['candidates'][0]['place_id']

        url2 = "https://maps.googleapis.com/maps/api/place/details/json?place_id={}&fields=name%2Ctype%2Cformatted_address&key={}".format(place_id, api_key)

        payload={}
        headers = {}

        response2 = requests.request("GET", url2, headers=headers, data=payload)
        res = ast.literal_eval(response2.text)['result']

        print(row['name'].upper(), row['street'].lower(), row['city'].lower(), row['state'].lower(), row['zip'])
        print(res['name'])
        print(res['formatted_address'])
        print(res['types'])
        print()
        print('+++++')
        
        
    except:
        print('ERROR:', row['name'], row['city'].lower(), row['state'].lower())
        print('++++++')
# Out:
# SOUTHWEST WESLEYAN CHURCH 4421 sw 14th ave cape coral fl 33914-6334
# Diplomat Wesleyan Church
# 1833 Diplomat Pkwy E, Cape Coral, FL 33909, USA
# ['church', 'place_of_worship', 'point_of_interest', 'establishment']
#
# +++++
# RIO GRANDE VALLEY JUNIOR VOLLEYBALL 905 crown cir edinburg tx 78539-7017
# University of Texas Rio Grande Valley Volleyball
# UTRGV Fieldhouse, N 5th Ave, Edinburg, TX 78539, USA
# ['university', 'point_of_interest', 'establishment']
#
# +++++
# MUSIC THEATRE WEST po box 3542 logan ut 84323-3542
# Music Theatre West
# 785 E Clover Cir, Logan, UT 84321, USA
# ['point_of_interest', 'establishment']
#
# +++++
# PARITY HUB INC 3334 lincoln ave san diego ca 92104-2112
# Hera Hub Sorrento Valley
# 4010 Sorrento Valley Blvd #400, San Diego, CA 92121, USA
# ['point_of_interest', 'establishment']
#
# +++++
# EL CENTRO DE RESTAURACION FAMILIAR 21700 calle prima moreno valley ca 92557-8577
# Iglesia ''Restauración Jireh''
# ...

# %%
address = "byers cemetery trust fund, gainesboro, tn"
api_key = "AIzaSyCNh5Hdo6NCnx1-wvKgSIxrInJorxOBPks"
url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={}&inputtype=textquery&key={}".format(address, api_key)

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "candidates" : [
#       {
#          "place_id" : "ChIJBxxBuOnhZogR2viBjewHFEw"
#       }
#    ],
#    "status" : "OK"
# }

# %%
response.status_code
# Out:
# 200

# %%
place_id = json.loads(response.text)['candidates'][0]['place_id']

url2 = "https://maps.googleapis.com/maps/api/place/details/json?place_id={}&fields=name%2Ctype%2Cformatted_address&key={}".format(place_id, api_key)

payload={}
headers = {}

response2 = requests.request("GET", url2, headers=headers, data=payload)

print(response2.text)
# Out:
# {
#    "html_attributions" : [],
#    "result" : {
#       "formatted_address" : "4061-4071 Flynns Creek Rd, Gainesboro, TN 38562, USA",
#       "name" : "Byers Cemetery",
#       "types" : [ "cemetery", "point_of_interest", "establishment" ]
#    },
#    "status" : "OK"
# }

# %%
address = "8313 PRATT LAKE AVE SE, ALTO, MI, 49302-9610"
api_key = "AIzaSyCNh5Hdo6NCnx1-wvKgSIxrInJorxOBPks"
url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={}&inputtype=textquery&key={}".format(address, api_key)

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)

place_id = json.loads(response.text)['candidates'][0]['place_id']

url2 = "https://maps.googleapis.com/maps/api/place/details/json?place_id={}&fields=name%2Ctype%2Cformatted_address&key={}".format(place_id, api_key)

payload={}
headers = {}

response2 = requests.request("GET", url2, headers=headers, data=payload)

print(response2.text)
# Out:
# {
#    "candidates" : [
#       {
#          "place_id" : "ChIJrWFJLhhBGIgRyrQ_tCZQRrA"
#       }
#    ],
#    "status" : "OK"
# }
#
# {
#    "html_attributions" : [],
#    "result" : {
#       "formatted_address" : "8313 Pratt Lake Ave SE, Alto, MI 49302, USA",
#       "name" : "8313 Pratt Lake Ave SE",
#       "types" : [ "premise" ]
#    },
#    "status" : "OK"
# }
